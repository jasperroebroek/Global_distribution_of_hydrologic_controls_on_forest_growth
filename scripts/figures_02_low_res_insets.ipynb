# %%
import thesis
import geomappy as mp
import matplotlib.pyplot as plt

# %%
thesis.draw_thesis_location_zoom((-93, 29, -78, 44))
plt.savefig("figures/si_inset_mississippi.png", bbox_inches='tight', pad_inches=0, dpi=300)

# %%
thesis.draw_thesis_location_zoom((70,8,85,23))
plt.savefig("figures/si_inset_india.png", bbox_inches='tight', pad_inches=0, dpi=300)

# %%
thesis.draw_thesis_location_zoom((7, 35, 22, 50))
plt.savefig("figures/si_inset_italy.png", bbox_inches='tight', pad_inches=0, dpi=300)

# %%
thesis.draw_thesis_location_zoom((142, -35, 158, -20))
plt.savefig("figures/si_inset_australia.png", bbox_inches='tight', pad_inches=0, dpi=300)

# %%
thesis.draw_thesis_location_zoom((15, -7, 30, 8))
plt.savefig("figures/si_inset_congo.png", bbox_inches='tight', pad_inches=0, dpi=300)
